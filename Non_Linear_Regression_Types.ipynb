# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat10-01/machine-learning/blob/master/Non_Linear_Regression_Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(-5.0, 5.0, 0.1)
# we can adjust the slope and intercept to verify the changes in the graph
y = 2*(x) + 3
y_noise = 2 * np.random.normal(size=x.size)
ydata = y + y_noise
# with a figure of size (8,6)
plt.figure(figsize=(8,6))
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %%
# we try same with cubic polynomial
x = np.arange(-5.0, 5.0, 0.1)
y = 1*(x**3) + 1*(x**2) + 1*x + 3
y_noise = 20 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %%
# lets try quadratic polynomial
x = np.arange(-5.0, 5.0, 0.1)
y = np.power(x,2)
y_noise = 2 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %%
# now lets try eponential function
X = np.arange(-5.0, 5.0, 0.1)
Y= np.exp(X)
Y_noise = 10*np.random.normal(size=X.size)
Ydata = Y + Y_noise
plt.plot(X,Ydata, 'bo')
plt.plot(X,Y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %%
# logarithmic
X = np.arange(-5.0, 5.0, 0.1)
Y = np.log(X)
Y_noise = 0.2*np.random.normal(size=X.size)
Ydata = Y + Y_noise
plt.plot(X,Ydata, 'bo')
plt.plot(X,Y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log

# %%
# sigmoidal or logistic function
X = np.arange(-5.0, 5.0, 0.1)
Y = 1-4/(1+np.power(3, X-2))
Y_noise = 0.2*np.random.normal(size=X.size)
Ydata = Y + Y_noise
plt.plot(X,Ydata, 'bo')
plt.plot(X,Y, 'r')
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()
